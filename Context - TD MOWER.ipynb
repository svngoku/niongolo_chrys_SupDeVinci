# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_log_error

# %%
momer_market_snapshot = pd.read_csv('mower_market_snapshot.csv', delimiter=";")
momer_market_snapshot
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
momer_market_snapshot.loc[:,['id', 'attractiveness']].head(5)
# Out:
#       id  attractiveness
# 0  18377        0.650648
# 1  19363        0.699792
# 2  19641        0.632129
# 3  18728        0.810730
# 4  18722        0.757614

# %%
# Trie du DataFrame
momer_market_snapshot.sort_values(by='prod_cost', ascending=False, na_position='first').head(30)
# Out:
#        capacity  failure_rate     id      margin       price prod_cost  \
# 107   31.019904      0.038149  19522  658.116184  411.087712       NaN
# 135   23.340049      0.039023  19596  726.196516  396.773981       NaN
# 170   34.857361      0.114097  18964  241.552664   72.970497       NaN
# 232   41.875278      0.096177  18736  291.932051  891.665482       NaN
# 280   33.383391      0.091738  18359  260.868096  869.049664       NaN
# 331   35.137522      0.093361  19251  262.668491   77.213051       NaN
# 471   44.813757      0.102862  18379  259.776821   72.035083       NaN
# 607   62.926054      0.228961  18806   66.590674  843.474741       NaN
# 711   50.760451      0.275969  19381   60.069105  401.325676       NaN
# 732   39.691240      0.227008  18535   61.127369  389.408396       NaN
# 795   59.270658      0.201919  19399   60.991972  397.807476       NaN
# 804   44.467231      0.191641  19038   65.094740  861.597824       NaN
# ...

# %%
#
momer_market_snapshot.isnull().sum(axis=0)
# Out:
# capacity           0
# failure_rate       0
# id                 0
# margin             0
# price              0
# prod_cost         18
# product_type       0
# quality            0
# warranty           0
# market_share       0
# attractiveness     0
# dtype: int64

# %%
#momer_market_snapshot.sort_values(by='prod_cost', ascending=False).head(100)
momer_market_snapshot["prod_cost"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1394    False
# 1395    False
# 1396    False
# 1397    False
# 1398    False
# Name: prod_cost, Length: 1399, dtype: bool

# %%
momer_market_snapshot["prod_cost"]
# Out:
# 0       195.03551928211797
# 1       151.31809934886763
# 2       178.13731921134948
# 3       162.82946157588628
# 4       141.48693796090603
#                ...
# 1394    11.498540481074583
# 1395    11.380588736668567
# 1396               unknown
# 1397     9.794196773761458
# 1398    10.696216086742934
# Name: prod_cost, Length: 1399, dtype: object

# %%
momer_market_snapshot['prod_cost'].str.contains('unknow')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: prod_cost, dtype: object

# %%
momer_market_snapshot.fillna(momer_market_snapshot['prod_cost'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3e6efc95e79c> in <module>
# ----> 1 momer_market_snapshot.fillna(momer_market_snapshot['prod_cost'].mean())
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11472         if level is not None:
#   11473             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11474         return self._reduce(
#   11475             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11476         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
# ...

# %%
# RMSLE pour l'évaluation
def RMSLE(y_true:np.ndarray, y_pred:np.ndarray) -> np.float64:
    """
        The Root Mean Squared Log Error (RMSLE) metric 
        
        :param y_true: The ground truth labels given in the dataset
        :param y_pred: Our predictions
        :return: The RMSLE score
    """
    n = len(y_true)
    msle = np.mean([(np.log(y_pred[i] + 1) - np.log(y_true[i] + 1)) ** 2.0 for i in range(n)])
    return np.sqrt(msle)
